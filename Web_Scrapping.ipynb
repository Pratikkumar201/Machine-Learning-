# %%
import requests

from bs4 import BeautifulSoup

# Accessing a website to scrap
url = 'https://news.yahoo.com/'

# Send get request to the URL

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

headlines = soup.find_all('h3')

#print(soup)
#print(headlines)

for headline in headlines:
  print(headline.text)

# %%
import requests
from bs4 import BeautifulSoup

url1='https://timesofindia.indiatimes.com/'

response = requests.get(url1)
soup1=BeautifulSoup(response.text, 'html.parser')

headlines1 = soup1.find_all('div')
for headline1 in headlines1:
  print(headline1.text)
# Out:
# EditionININUSSat, Mar 09, 2024 | Updated 03.56PM ISTRead ePaperSign InTOI+VideosCityMetro CitiesmumbaidelhibengaluruHyderabadkolkatachennaiOther  regionmysurunagpurnashiknavi mumbainoidapatnapuducherrypuneraipurrajkotranchithanesalemshillongshimlasrinagarsurattrichythiruvananthapuramudaipurvadodaravaranasivijayawadavisakhapatnamphotosWeb StoriesIndiafeaturedAyodhya Ram TempleSaving Our StripesTimes EvokeMaharashtraDelhiKarnatakaTamil NaduTelanganaUttar PradeshWest BengalGujaratMadhya PradeshBiharChandigarhRajasthanArunachal PradeshAndhra PradeshAssamChhattisgarhGoaHaryanaHimachal PradeshJammu KashmirJharkhandKeralaManipurMeghalayaMizoramNagalandOdishaPunjabSikkimTripuraUttarakhandAnd
# ...

# %%
import pandas as pd

data={
    'name': ['Pratik', 'Abhay', 'Abhishek', 'Kunal'],
    'Age' : [23,19,22,25],
    'City' :['Varanasi', 'Mirzapur','Jharkhand', 'Kolkata'],
    'GPA' : [8.1,7.8,8.2,9.2]
}

df=pd.DataFrame(data)
print(df)
# Out:
#        name  Age       City  GPA
# 0    Pratik   23   Varanasi  8.1
# 1     Abhay   19   Mirzapur  7.8
# 2  Abhishek   22  Jharkhand  8.2
# 3     Kunal   25    Kolkata  9.2

# %%
df['name']
# Out:
# 0      Pratik
# 1       Abhay
# 2    Abhishek
# 3       Kunal
# Name: name, dtype: object

# %%
df[['name','GPA']]
# Out:
#        name  GPA
# 0    Pratik  8.1
# 1     Abhay  7.8
# 2  Abhishek  8.2
# 3     Kunal  9.2

# %%
df[df['Age']>21]
# Out:
#        name  Age       City  GPA
# 0    Pratik   23   Varanasi  8.1
# 2  Abhishek   22  Jharkhand  8.2
# 3     Kunal   25    Kolkata  9.2
