# %%
import yfinance as yf

# %%
ticker="TATAPOWER.NS"
yf.download(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1996-01-01   11.580205   11.662232   11.488529   11.628456    5.920809
# 1996-01-02   11.628456   11.739433   11.396852   11.483704    5.847106
# 1996-01-03   11.483704   11.599506   11.392027   11.411327    5.810255
# 1996-01-04   11.411327   11.387202   11.155598   11.242449    5.724267
# 1996-01-05   11.242449   11.483704   11.097697   11.464403    5.837279
# ...                ...         ...         ...         ...         ...
# 2023-05-26  212.250000  213.800003  210.649994  212.199997  212.199997
# 2023-05-29  213.000000  217.699997  211.699997  217.000000  217.000000
# 2023-05-30  218.000000  218.449997  215.000000  216.899994  216.899994
# 2023-05-31  216.899994  219.000000  212.899994  213.550003  213.550003
# 2023-06-01  213.949997  217.000000  213.000000  215.300003  215.300003
#
#               Volume
# Date
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data=pd.read_csv("/content/drive/MyDrive/archive (1)/Shark Tank India Dataset.csv")

# %%
data.head()
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# 4                       Brain Development Course     0                50.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0        16.00  ...             1
# ...

# %%
data.tail()
# Out:
#      episode_number  pitch_number     brand_name                    idea  \
# 112              34           113  Green Protein     Plant-Based Protein
# 113              34           114        On2Cook  Fastest Cooking Device
# 114              35           115  Jain Shikanji                Lemonade
# 115              35           116          Woloo         Washroom Finder
# 116              35           117   Elcare India    Carenting for Elders
#
#      deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 112     0                60.0         2.0         3000.0          0.0
# 113     0               100.0         1.0        10000.0          0.0
# 114     1                40.0         8.0          500.0         40.0
# 115     0                50.0         4.0         1250.0          0.0
# 116     0               100.0         2.5         4000.0          0.0
#
#      deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# ...

# %%
data.shape
# Out:
# (117, 28)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
data.describe()
# Out:
#        episode_number  pitch_number        deal  pitcher_ask_amount  \
# count      117.000000    117.000000  117.000000          117.000000
# mean        18.735043     59.000000    0.555556          319.854709
# std         10.070778     33.919021    0.499041         2767.842777
# min          1.000000      1.000000    0.000000            0.001010
# 25%         10.000000     30.000000    0.000000           45.000000
# 50%         19.000000     59.000000    1.000000           50.000000
# 75%         27.000000     88.000000    1.000000           80.000000
# max         35.000000    117.000000    1.000000        30000.000000
#
#        ask_equity  ask_valuation  deal_amount  deal_equity  deal_valuation  \
# count  117.000000     117.000000   117.000000   117.000000      117.000000
# mean     5.188034    3852.462479    31.982915     8.963504      467.104872
# std      3.892121   11931.601957    36.687391    13.106769      919.988864
# ...

# %%
# drop duplicate data

# data.drop_duplicates(["res-id"],keep='first',inplace=True)
# data.shape()

# data.isnull().sum()

# %%
data.isnull().sum()
# Out:
# episode_number           0
# pitch_number             0
# brand_name               0
# idea                     0
# deal                     0
# pitcher_ask_amount       0
# ask_equity               0
# ask_valuation            0
# deal_amount              0
# deal_equity              0
# deal_valuation           0
# ashneer_present          0
# anupam_present           0
# aman_present             0
# namita_present           0
# vineeta_present          0
# peyush_present           0
# ghazal_present           0
# ashneer_deal             0
# anupam_deal              0
# aman_deal                0
# namita_deal              0
# vineeta_deal             0
# peyush_deal              0
# ghazal_deal              0
# total_sharks_invested    0
# amount_per_shark         0
# equity_per_shark         0
# dtype: int64

# %%
# Percentage of companies got investment or not ?
got_in=data[data['deal_amount']>0.0].shape
not_in=data[data['deal_amount']==0.0].shape
print("The number of companies who got the Investment: ",got_in[0])
print("The number of companies who didn't got the Investment: ",not_in[0])
print("\n---------\n")
list1=["Got Investment", "Not received Investment"]
plt.pie([got_in[0],not_in[0]],labels=list1,autopct='%.1f%%')
plt.title('Number of companies which got Investment or not: ')
plt.show()
# Out:
# The number of companies who got the Investment:  65
# The number of companies who didn't got the Investment:  52
#
# ---------

# %%
data[data['total_sharks_invested']==5]
# Out:
#     episode_number  pitch_number             brand_name                 idea  \
# 15               6            16            Skippi Pops             Ice-Pops
# 49              17            50  Find Your Kicks India       Sneaker Resale
# 63              20            64               IN A CAN        Can Cocktails
# 79              25            80    Sunfox Technologies  Portable ECG Device
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 15     1                45.0         5.0          900.0        100.0
# 49     1                50.0        10.0          500.0         50.0
# 63     1                50.0         2.0         2500.0        100.0
# 79     1               100.0         2.0         5000.0        100.0
#
#     deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# 15         15.0  ...             1            1          1            1
# 49         25.0  ...             1            1          1            1
# ...

# %%
total_shark=data[data['total_sharks_invested']==5]
figure=px.bar(total_shark,x='brand_name',y='deal_amount',title="Five shark Deal Brands and the total investment ",template='plotly_dark')
figure.show()

# %%
#  Highest pitch ask amount
high=data[data['pitcher_ask_amount']>100]
figure=px.bar(high,x='brand_name',y='pitcher_ask_amount',title='Highest Pitch Ask Amount:',text_auto=True,template='plotly_dark')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Ask Equity and Deal Equity of Highest Pitch Ask Amount Brand
figure=px.bar(high,x='brand_name',y='ask_equity',title="Ask Equity and Deal Equity of Highest Pitch Ask Amount Brand",template='plotly_dark')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
